# %%
import os
os.chdir("..")

# %%
from tension_analyzer.tension_visualizer import TensionVisualizer, quick_load_and_visualize

# %%
viz = TensionVisualizer()
viz.load_tension_data("tension_analyzer/outputs/tension_data/tension_테라리아_20250610_172642.json")
# Out:
# ✅ TensionVisualizer 초기화 완료
#    얼굴 이미지 디렉토리: video_analyzer/preprocessed_data/debug_faces/chimchakman
# ✅ 텐션 데이터 로드 완료
#    영상명: b_023_2025년_05월_20일__테라리아_2일차_6570.0_6590.0
#    지속시간: 19.9초
#    텐션 포인트: 78개
# True

# %%
viz.plot_tension_curves()
# Out:
# 📊 텐션 통계:
#    평균: 3.61
#    최대: 4.83
#    최소: 2.94
#    표준편차: 0.45
#    음성 활동 비율: 2.5%

# %%
viz.plot_emotion_pie_chart()
# Out:
# ✅ 감정 데이터 로드: (80, 10)
#    Anger: 전체 80개, 양수 80개, 평균 1.0397
#    Contempt: 전체 80개, 양수 11개, 평균 0.2356
#    Disgust: 전체 80개, 양수 0개, 평균 0.0000
#    Fear: 전체 80개, 양수 21개, 평균 0.2298
#    Happiness: 전체 80개, 양수 0개, 평균 0.0000
#    Neutral: 전체 80개, 양수 80개, 평균 3.1530
#    Sadness: 전체 80개, 양수 80개, 평균 1.8271
#    Surprise: 전체 80개, 양수 80개, 평균 2.4990
# 📊 양수값만 필터링한 감정 평균값: [1.03969717 0.23563053 0.         0.22982658 0.         3.15303278
#  1.82714152 2.49900746]
#    데이터 범위: 최소 0.000, 최대 3.153
# 🎭 주요 감정:
#    1. Neutral: 3.153
#    2. Surprise: 2.499
#    3. Sadness: 1.827

# %%
viz.debug_faces_dir = "video_analyzer/preprocessed_data/chimchakman_f_004_급_유턴_10_240_20250610/chimchakman"
viz.show_emotion_peak_faces(top_n=1)
# Out:
# ✅ 감정 데이터 로드: (80, 10)
# ✅ HDF5에서 얼굴 폴더 자동 감지: video_analyzer\preprocessed_data\debug_faces\chimchakman_b_023_2025년_05월_20일__테라리아_2일차_65700_65900_20250610\chimchakman
# 🎭 감정 피크 표시 완료 (7개: 7감정 + VA)
